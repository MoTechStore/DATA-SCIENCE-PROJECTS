# %%
import numpy as np
import pandas as pd
from pandas import read_csv
filename = 'breastCancer.csv'
data = read_csv(filename)
data.head(5)
# Read data as pandas dataframe
# Show first 5 rows
# Out:
#    AGE  MENOPAUSE  TUMOUR_SIZE  INV_NODES  NODE_CAPS  DEG_MALIG  BREAST  \
# 0    2          2            2          0          1          2       1
# 1    3          0            2          0          0          0       1
# 2    3          0            6          0          0          1       0
# 3    2          2            6          0          1          2       1
# 4    2          2            5          4          1          1       0
#
#    BREAST_QUAD  IRRIDIAT  CLASS
# 0            2         0      1
# 1            0         0      0
# 2            1         0      1
# 3            1         1      0
# 4            4         0      1

# %%
data.drop([0,1], axis=0, inplace=True)
# This will delete row 0 and row 1

# %%
# To see the changes after deleting row 0 and row 1
data.head()
# Out:
#    AGE  MENOPAUSE  TUMOUR_SIZE  INV_NODES  NODE_CAPS  DEG_MALIG  BREAST  \
# 2    3          0            6          0          0          1       0
# 3    2          2            6          0          1          2       1
# 4    2          2            5          4          1          1       0
# 5    3          2            4          4          0          1       1
# 6    3          0            7          0          0          2       0
#
#    BREAST_QUAD  IRRIDIAT  CLASS
# 2            1         0      1
# 3            1         1      0
# 4            4         0      1
# 5            2         1      0
# 6            2         0      0

# %%
data.drop([5,6,7], axis=0, inplace=True)
# This will delete row 5, 6 and row 7

# %%
# To see the changes after row 5, 6 and row 7
data.head()
# Out:
#    AGE  MENOPAUSE  TUMOUR_SIZE  INV_NODES  NODE_CAPS  DEG_MALIG  BREAST  \
# 2    3          0            6          0          0          1       0
# 3    2          2            6          0          1          2       1
# 4    2          2            5          4          1          1       0
# 8    2          2            0          0          0          1       1
# 9    2          0            7          2          1          1       1
#
#    BREAST_QUAD  IRRIDIAT  CLASS
# 2            1         0      1
# 3            1         1      0
# 4            4         0      1
# 8            3         0      0
# 9            2         1      0
